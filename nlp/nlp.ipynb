# %%
from google.colab import drive

# %%
drive.mount('/content/drive',  force_remount=True)
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
cd /content/drive/My Drive/AI_Experiment/nlp/
# Out:
# /content/drive/My Drive/AI_Experiment/nlp

# %%
ls
# Out:
# dataset/                      sentence_data.py
# language_model_lstm.py        trained_model/
# language_model_lstm_test.py   translator_model.py
# language_model_lstm_train.py  translator_model_test.py
# language_model_rnn.py         translator_model_train.py
# language_model_rnn_test.py    Untitled0.ipynb
# language_model_rnn_train.py

# %%
! python language_model_rnn_train.py
# Out:
# 1 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 49.7616014547348.
# 2 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 39.645532053232195.
# 3 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 34.54668991923332.
# 4 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 29.91292345547676.
# 5 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 25.571969639778136.
# 6 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 21.58088686621189.
# 7 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 18.029935260415076.
# 8 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 15.052763337016106.
# 9 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 12.511654753714799.
# 10 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 10.427518870592117.

# %%
! python language_model_rnn_test.py
# Out:
# input initial words : 僕
# 僕
# の
# チョコレート
# は
# あなた
# が
# スチュワーデス
# に
# 覆いかぶさっていた
# 。

# %%
! python language_model_lstm_train.py
# Out:
# 1 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 51.462092577934264.
# 2 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 42.79314293384552.
# 3 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 37.44636049127579.
# 4 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 32.52581620788574.
# 5 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 28.059047828674316.
# 6 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 24.04839199876785.
# 7 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 20.511561862707136.
# 8 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 17.35536985039711.
# 9 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 14.68160003209114.
# 10 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 12.481440108418465.

# %%
! python language_model_lstm_test.py
# Out:
# input initial words : dghdfh
# <UNKNOWN>
# of
# the
# encyclopedia
# was
# published
# .

# %%
! python translator_model_train.py
# Out:
# 1 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 34.66617678833008.
# 2 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 27.88154372215271.
# 3 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 25.8245856628418.
# 4 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 24.046924964904786.
# 5 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 22.344378887653352.
# 6 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 20.56846266078949.
# 7 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 18.91301422905922.
# 8 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 17.305085503458976.
# 9 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 15.822597889244557.
# 10 / 10 epoch start.
# 100 / 1000 sentences finished.
# 200 / 1000 sentences finished.
# 300 / 1000 sentences finished.
# 400 / 1000 sentences finished.
# 500 / 1000 sentences finished.
# 600 / 1000 sentences finished.
# 700 / 1000 sentences finished.
# 800 / 1000 sentences finished.
# 900 / 1000 sentences finished.
# 1000 / 1000 sentences finished.
# mean loss = 14.474310808122159.

# %%
! python translator_model_test.py
# Out:
# input an english sentence : she is neko .
# 彼女は<UNKNOWN><UNKNOWN>を<UNKNOWN>。
